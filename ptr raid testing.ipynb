# %%
import requests
import os
import json
import joblib
import pandas as pd
import time
from math import ceil
from dotenv import load_dotenv
from tqdm import tqdm

# %%
DATA_DIR = './data/'

# %%
def getQuery(query, params=None):
    header = {"Authorization": f'Bearer {token}'}
    publicURL = 'https://www.warcraftlogs.com/api/v2/client'
    
    if params is None:
        response = requests.get(url=publicURL, headers=header, params={'query':query})
    else:
        data = {'query':query, 'variables':params}
        response = requests.get(url=publicURL, headers=header, json=data)
    return response

# %%
def getRateLimitData():
    query = """query{
        rateLimitData{
            limitPerHour
            pointsSpentThisHour
            pointsResetIn
        }
    }"""
    
    response = getQuery(query)
    return response.json()['data']['rateLimitData']

# %%
def getReports(zoneID, max_page=1):
    """max_page = number of pages to retrieve (maximum 25 currently)
       max_page = -1 to retrieve all pages"""
    assert max_page == -1 or max_page in range(1, 26)
            
    query = """query($zone:Int, $page:Int){
        reportData{
            reports(zoneID:$zone, page:$page){
                has_more_pages
                data{
                    code
                    startTime
                }
            }
        }
    }"""
    
    reports = list()
    startTimes = list()
 
    if max_page == -1:
        page = 1
        has_more_pages = True
        while has_more_pages:
            response = getQuery(query, params={'zone':zoneID, 'page':page})
            response = response.json()['data']['reportData']['reports']
            has_more_pages = response['has_more_pages']
            data = response['data']
            reports += [report['code'] for report in data]
            startTimes += [report['startTime'] for report in data]
            page += 1
    else:
        for page in range(1, max_page+1):
            response = getQuery(query, params={'zone':zoneID, 'page':page})
            response = response.json()['data']['reportData']['reports']
            if not response['has_more_pages']:
                break
            data = response['data']
            reports += [report['code'] for report in data]
            startTimes += [report['startTime'] for report in data]
    
    dates = [str(pd.to_datetime(time, unit='ms', utc=True).tz_convert('US/Eastern').date()) for time in startTimes]
    
    return dict(zip(reports, dates))

# %%
def getReportDate(reportID):
    """Returns Pandas date of Report Start in US/Eastern Time"""
    query = """query($reportID:String){
        reportData{
            report(code:$reportID){
                startTime
            }
        }
    }"""
    
    response = getQuery(query, params={'reportID':reportID})
    startTime = response.json()['data']['reportData']['report']['startTime']
    datetime = pd.to_datetime(startTime, unit='ms', utc=True).tz_convert('US/Eastern')
    
    return str(datetime.date())

# %%
def getFights(reportID, includeTrash=False):
    query = """query($reportID:String){
        reportData{
            report(code:$reportID){
                fights{
                    difficulty
                    encounterID
                    id
                    kill
                }
            }
        }
    }"""
    
    response = getQuery(query, params={'reportID':reportID})
    fights = response.json()['data']['reportData']['report']['fights']
    
    if not includeTrash:
        fights = [fight for fight in fights if fight['encounterID'] in bosses.values()]
        
    return fights

# %%
def getFightsParallel(reportID, includeTrash=False):
    fights = getFights(reportID, includeTrash)
    for fight in fights:
        fight['reportID'] = reportID
        
    return fights

# %%
def getFightTables(reportID, fightID):
    #duration, damage done, healing done, etc
    query = """query($reportID:String, $fightIDs:[Int]){
        reportData{
            report(code:$reportID){
                table(fightIDs:$fightIDs)
            }
        }
    }"""
    
    response = getQuery(query, params={'reportID':reportID, 'fightIDs':[fightID]})
    
    tables = response.json()['data']['reportData']['report']['table']['data']
    tables['reportID'] = reportID
    tables['fightID'] = fightID
    
    del tables['damageTaken']
    del tables['playerDetails']
    del tables['logVersion']
    del tables['gameVersion']
    
    return tables

# %%
def transformFightTable(table):    
    damageDone = {player['name']:player['total'] for player in table['damageDone']}
    healingDone = {player['name']:player['total'] for player in table['healingDone']}
    
    deaths = {}
    for death in table['deathEvents']:
        deaths[death['name']] = deaths.get(death['name'], 0) + 1
    
    output = list()
    for player in table['composition']:
        try:
            spec = player['specs'][0]['spec']
            role = player['specs'][0]['role']
        except:
            spec = ""
            role = ""
            
        output.append({'awda'
           'Report ID':table['reportID'],
           'Fight ID':table['fightID'],
           'Name':player['name'],
           'Class':player['type'],
           'Specialization':spec,
           'Role':role,
           'Damage Done':damageDone.get(player['name'], 0),
           'Healing Done':healingDone.get(player['name'], 0),
           'Death Count':deaths.get(player['name'], 0)   
        })
    
    return output

# %%
load_dotenv()
CLIENT_ID = os.environ['CLIENT_ID']
CLIENT_SECRET = os.environ['CLIENT_SECRET']

# %%
auth=(CLIENT_ID, CLIENT_SECRET)
data={'grant_type':'client_credentials'}
url = 'https://www.warcraftlogs.com/oauth/token'
response = requests.post(url=url, data=data, auth=auth)
token = response.json().get('access_token')

# %%
zoneID = 42
bosses = {
    'Vexie and the Geargrinders':3009,
    'Cauldron of Carnage':3010,
    'Rik Reverb':3011,
    'Stix Bunkjunker':3012,
    'Sprocketmonger Lockenstock':3013,
    'One-Armed Bandit':3014,
    "Mug'Zee, Heads of Security":3015,
    'Chrome King Gallywix':3016
}
difficulties = {
    'LFR':1,
    'Normal':3,
    'Heroic':4,
    'Mythic':5
}

# %% [markdown]
# # Report IDs

# %%
reports = getReports(zoneID=zoneID, max_page=-1)
ptrReports = list(reports.keys())

# %%
with open(DATA_DIR+'ptrReports.csv', 'w') as file:
    file.write('Report ID, Date')
    file.write('\n')
    for report, date in reports.items():
        file.write(report)
        file.write(',')
        file.write(date)
        file.write('\n')

# %% [markdown]
# # Fight Metadata

# %%
print(f'Total Tasks: {len(ptrReports)}')

all_jobs = [joblib.delayed(getFightsParallel)(reportID) for reportID in ptrReports]
results = joblib.Parallel(n_jobs=joblib.cpu_count(), verbose=10)(all_jobs)

fightInfo = [fight for report in results for fight in report]
# Out:
# Total Tasks: 766
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   2 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=24)]: Done  13 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=24)]: Done  24 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=24)]: Done  37 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=24)]: Done  50 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=24)]: Done  65 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=24)]: Done  80 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=24)]: Done  97 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=24)]: Done 114 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=24)]: Done 133 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=24)]: Done 152 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=24)]: Done 173 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=24)]: Done 194 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=24)]: Done 217 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=24)]: Done 240 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=24)]: Done 265 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=24)]: Done 290 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=24)]: Done 317 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=24)]: Done 344 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=24)]: Done 373 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=24)]: Done 402 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=24)]: Done 433 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=24)]: Done 464 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=24)]: Done 497 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=24)]: Done 530 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=24)]: Done 565 tasks      | elapsed:   42.0s
# [Parallel(n_jobs=24)]: Done 600 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=24)]: Done 637 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=24)]: Done 674 tasks      | elapsed:   50.0s
# [Parallel(n_jobs=24)]: Done 713 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=24)]: Done 766 out of 766 | elapsed:   55.9s finished

# %%
with open(DATA_DIR+'fightMetadata.csv', 'w') as file:
    file.write(','.join(['Difficulty', 'Encounter ID', 'Fight ID', 'Killed', 'Report ID']))
    file.write('\n')
    for fight in fightInfo:
        file.write(','.join([str(value) for value in fight.values()]))
        file.write('\n')

# %% [markdown]
# # Fight Data

# %%
### Parallel Processing ###
allResults = list()
totalFights = len(fightInfo)

curIndex = 0
while curIndex < totalFights:
    rateLimitData = getRateLimitData()
    pingsRemaining = rateLimitData['limitPerHour'] - ceil(rateLimitData['pointsSpentThisHour'])
    timeRemaining = rateLimitData['pointsResetIn']
    
    if pingsRemaining < 50:
        sleepTime = timeRemaining + 60
        for _ in tqdm(range(sleepTime), desc=f'Sleep {sleepTime} seconds'):
            time.sleep(1)
            
        #reupdate rate limit data
        rateLimitData = getRateLimitData()
        pingsRemaining = rateLimitData['limitPerHour'] - rateLimitData['pointsSpentThisHour']
        timeRemaining = rateLimitData['pointsResetIn']
        
    endIndex = min(curIndex + pingsRemaining - 50, totalFights) #-50 to be safe and not error out from running over
    
    print(f'Total Tasks: {endIndex-curIndex}')
    all_jobs = [joblib.delayed(getFightTables)(fight['reportID'], fight['id']) 
                for fight in tqdm(fightInfo[curIndex:endIndex], total=(endIndex-curIndex))]
    results = joblib.Parallel(n_jobs=joblib.cpu_count(), verbose=10)(all_jobs)
    
    allResults += results
    curIndex = endIndex
# Out:
# Total Tasks: 19397
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   2 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=24)]: Done  13 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=24)]: Done  24 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=24)]: Done  37 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=24)]: Done  50 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=24)]: Done  65 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=24)]: Done  80 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=24)]: Done  97 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=24)]: Done 114 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=24)]: Done 133 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=24)]: Done 152 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=24)]: Done 173 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=24)]: Done 194 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=24)]: Done 217 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=24)]: Done 240 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=24)]: Done 265 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=24)]: Done 290 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=24)]: Done 317 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=24)]: Done 344 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=24)]: Done 373 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=24)]: Done 402 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=24)]: Done 433 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=24)]: Done 464 tasks      | elapsed:   37.0s
# [Parallel(n_jobs=24)]: Done 497 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=24)]: Done 530 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=24)]: Done 565 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=24)]: Done 600 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=24)]: Done 637 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=24)]: Done 674 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=24)]: Done 713 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=24)]: Done 752 tasks      | elapsed:   58.5s
# [Parallel(n_jobs=24)]: Done 793 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=24)]: Done 834 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=24)]: Done 877 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=24)]: Done 920 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=24)]: Done 965 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=24)]: Done 1010 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=24)]: Done 1057 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=24)]: Done 1104 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=24)]: Done 1153 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=24)]: Done 1202 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=24)]: Done 1253 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=24)]: Done 1304 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=24)]: Done 1357 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=24)]: Done 1410 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=24)]: Done 1465 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=24)]: Done 1520 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=24)]: Done 1577 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=24)]: Done 1634 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=24)]: Done 1693 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=24)]: Done 1752 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=24)]: Done 1813 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=24)]: Done 1874 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=24)]: Done 1937 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=24)]: Done 2000 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=24)]: Done 2065 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=24)]: Done 2130 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=24)]: Done 2197 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=24)]: Done 2264 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=24)]: Done 2333 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=24)]: Done 2402 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=24)]: Done 2473 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=24)]: Done 2544 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=24)]: Done 2617 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=24)]: Done 2690 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=24)]: Done 2765 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=24)]: Done 2840 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=24)]: Done 2917 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=24)]: Done 2994 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=24)]: Done 3073 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=24)]: Done 3152 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=24)]: Done 3233 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=24)]: Done 3314 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=24)]: Done 3397 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=24)]: Done 3480 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=24)]: Done 3565 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=24)]: Done 3650 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=24)]: Done 3737 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=24)]: Done 3824 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=24)]: Done 3913 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=24)]: Done 4002 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=24)]: Done 4093 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=24)]: Done 4184 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=24)]: Done 4277 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=24)]: Done 4370 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=24)]: Done 4465 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=24)]: Done 4560 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=24)]: Done 4657 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=24)]: Done 4754 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=24)]: Done 4853 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=24)]: Done 4952 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=24)]: Done 5053 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=24)]: Done 5154 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=24)]: Done 5257 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=24)]: Done 5360 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=24)]: Done 5465 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=24)]: Done 5570 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=24)]: Done 5677 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=24)]: Done 5784 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=24)]: Done 5893 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=24)]: Done 6002 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=24)]: Done 6113 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=24)]: Done 6224 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=24)]: Done 6337 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=24)]: Done 6450 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=24)]: Done 6565 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=24)]: Done 6680 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=24)]: Done 6797 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=24)]: Done 6914 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=24)]: Done 7033 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=24)]: Done 7152 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=24)]: Done 7273 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=24)]: Done 7394 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=24)]: Done 7517 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=24)]: Done 7640 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=24)]: Done 7765 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=24)]: Done 7890 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=24)]: Done 8017 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=24)]: Done 8144 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=24)]: Done 8273 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=24)]: Done 8402 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=24)]: Done 8533 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=24)]: Done 8664 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=24)]: Done 8797 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=24)]: Done 8930 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=24)]: Done 9065 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=24)]: Done 9200 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=24)]: Done 9337 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=24)]: Done 9474 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=24)]: Done 9613 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=24)]: Done 9752 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=24)]: Done 9893 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=24)]: Done 10034 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=24)]: Done 10177 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=24)]: Done 10320 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=24)]: Done 10465 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=24)]: Done 10610 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=24)]: Done 10757 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=24)]: Done 10904 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=24)]: Done 11053 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=24)]: Done 11202 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=24)]: Done 11353 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=24)]: Done 11504 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=24)]: Done 11657 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=24)]: Done 11810 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=24)]: Done 11965 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=24)]: Done 12120 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=24)]: Done 12277 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=24)]: Done 12434 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=24)]: Done 12593 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=24)]: Done 12752 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=24)]: Done 12913 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=24)]: Done 13074 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=24)]: Done 13237 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=24)]: Done 13400 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=24)]: Done 13565 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=24)]: Done 13730 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=24)]: Done 13897 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=24)]: Done 14064 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=24)]: Done 14233 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=24)]: Done 14402 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=24)]: Done 14573 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=24)]: Done 14744 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=24)]: Done 14917 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=24)]: Done 15090 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=24)]: Done 15265 tasks      | elapsed: 20.0min
# [Parallel(n_jobs=24)]: Done 15440 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=24)]: Done 15617 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=24)]: Done 15794 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=24)]: Done 15986 out of 15986 | elapsed: 20.9min finished
# Total Tasks: 19397
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   2 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=24)]: Done  13 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=24)]: Done  24 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=24)]: Done  37 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=24)]: Done  50 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=24)]: Done  65 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=24)]: Done  80 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=24)]: Done  97 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=24)]: Done 114 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=24)]: Done 133 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=24)]: Done 152 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=24)]: Done 173 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=24)]: Done 194 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=24)]: Done 217 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=24)]: Done 240 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=24)]: Done 265 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=24)]: Done 290 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=24)]: Done 317 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=24)]: Done 344 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=24)]: Done 373 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=24)]: Done 402 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=24)]: Done 433 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=24)]: Done 464 tasks      | elapsed:   39.4s
# [Parallel(n_jobs=24)]: Done 497 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=24)]: Done 530 tasks      | elapsed:   43.9s
# [Parallel(n_jobs=24)]: Done 565 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=24)]: Done 600 tasks      | elapsed:   49.3s
# [Parallel(n_jobs=24)]: Done 637 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=24)]: Done 674 tasks      | elapsed:   55.4s
# [Parallel(n_jobs=24)]: Done 713 tasks      | elapsed:   58.0s
# [Parallel(n_jobs=24)]: Done 752 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=24)]: Done 793 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=24)]: Done 834 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=24)]: Done 877 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=24)]: Done 920 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=24)]: Done 965 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=24)]: Done 1010 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=24)]: Done 1057 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=24)]: Done 1104 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=24)]: Done 1153 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=24)]: Done 1202 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=24)]: Done 1253 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=24)]: Done 1304 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=24)]: Done 1357 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=24)]: Done 1410 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=24)]: Done 1465 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=24)]: Done 1520 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=24)]: Done 1577 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=24)]: Done 1634 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=24)]: Done 1693 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=24)]: Done 1752 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=24)]: Done 1813 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=24)]: Done 1874 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=24)]: Done 1937 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=24)]: Done 2000 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=24)]: Done 2065 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=24)]: Done 2130 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=24)]: Done 2197 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=24)]: Done 2264 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=24)]: Done 2333 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=24)]: Done 2402 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=24)]: Done 2473 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=24)]: Done 2544 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=24)]: Done 2617 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=24)]: Done 2690 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=24)]: Done 2765 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=24)]: Done 2840 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=24)]: Done 2917 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=24)]: Done 2994 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=24)]: Done 3073 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=24)]: Done 3152 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=24)]: Done 3233 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=24)]: Done 3314 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=24)]: Done 3411 out of 3411 | elapsed:  4.6min finished

# %%
metadata = [{'Report ID':fight['reportID'], 
             'Fight ID':fight['fightID'], 
             'Duration (ms)':fight['totalTime'], 
             'iLvl':fight['itemLevel']} for fight in allResults]

# %%
with open(DATA_DIR+'fightMetadata2.csv', 'w') as file:
    file.write(','.join(['Report ID', 'Fight ID', 'Duration (ms)', 'iLvl']))
    file.write('\n')
    
    for fight in metadata:
        file.write(','.join([str(value) for value in fight.values()]))
        file.write('\n')

# %%
#merge new metadata with old metadata

fightMetadata = pd.read_csv('./fightMetadata.csv')
newMetadata = pd.DataFrame(metadata)

mergedMetadata = pd.merge(left=fightMetadata, right=newMetadata, on=['Report ID', 'Fight ID'], how='left')

# %%
mergedMetadata.to_csv('./fightMetadata.csv', index=False)
os.remove(DATA_DIR+'fightMetadata2.csv') #metadata2 was just an intermediate file

# %%
fightData = [player for table in allResults for player in transformFightTable(table)]

# %%
with open(DATA_DIR+'fightData.csv', 'w', encoding='utf-8-sig') as file:
    file.write(','.join(['Report ID', 'Fight ID', 'Name', 'Class', 'Specialization', 'Role', 'Damage Done', 
                         'Healing Done', 'Death Count']))
    file.write('\n')
    
    for fight in fightData:
        file.write(','.join([str(value) for value in fight.values()]))
        file.write('\n')
